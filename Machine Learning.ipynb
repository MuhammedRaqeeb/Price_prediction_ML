# %% [markdown]
# # ___TOYOTA__  __CAR PRICE PREDICTION___

# %% [markdown]
# ![supra.jpg](attachment:supra.jpg)

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# reading the dataset
car  = pd.read_csv("C:\\Users\\USER\\Desktop\\Toyota_car.csv")

# %%
car.head(15)
# Out:
#     Unnamed: 0  Price   Age     KM FuelType    HP  MetColor  Automatic    CC  \
# 0            0  13500  23.0  46986   Diesel    90       1.0          0  2000
# 1            1  13750  23.0  72937   Diesel    90       1.0          0  2000
# 2            2  13950  24.0  41711   Diesel    90       NaN          0  2000
# 3            3  14950  26.0  48000   Diesel    90       0.0          0  2000
# 4            4  13750  30.0  38500   Diesel    90       0.0          0  2000
# 5            5  12950  32.0  61000   Diesel    90       0.0          0  2000
# 6            6  16900  27.0     ??   Diesel  ????       NaN          0  2000
# 7            7  18600  30.0  75889      NaN    90       1.0          0  2000
# 8            8  21500  27.0  19700   Petrol   192       0.0          0  1800
# 9            9  12950  23.0  71138   Diesel  ????       NaN          0  1900
# 10          10  20950  25.0  31461   Petrol   192       0.0          0  1800
# 11          11  19950  22.0  43610   Petrol   192       0.0          0  1800
# 12          12  19600  25.0  32189   Petrol   192       0.0          0  1800
# 13          13  21500  31.0  23000   Petrol   192       1.0          0  1800
# 14          14  22500  32.0  34131   Petrol   192       1.0          0  1800
#
#     Doors  Weight
# 0   three    1165
# 1       3    1165
# 2       3    1165
# 3       3    1165
# 4       3    1170
# 5       3    1170
# 6       3    1245
# 7       3    1245
# 8       3    1185
# 9       3    1105
# 10      3    1185
# 11      3    1185
# 12      3    1185
# 13      3    1185
# 14      3    1185

# %%
# Reading the dataset 
car = pd.read_csv('C:\\Users\\USER\\Desktop\\Toyota_car.csv' , index_col=0,na_values=["??","????"]) # Replace "??" and "???" into null values

# %%
car.head(15)
# Out:
#     Price   Age       KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 0   13500  23.0  46986.0   Diesel   90.0       1.0          0  2000  three
# 1   13750  23.0  72937.0   Diesel   90.0       1.0          0  2000      3
# 2   13950  24.0  41711.0   Diesel   90.0       NaN          0  2000      3
# 3   14950  26.0  48000.0   Diesel   90.0       0.0          0  2000      3
# 4   13750  30.0  38500.0   Diesel   90.0       0.0          0  2000      3
# 5   12950  32.0  61000.0   Diesel   90.0       0.0          0  2000      3
# 6   16900  27.0      NaN   Diesel    NaN       NaN          0  2000      3
# 7   18600  30.0  75889.0      NaN   90.0       1.0          0  2000      3
# 8   21500  27.0  19700.0   Petrol  192.0       0.0          0  1800      3
# 9   12950  23.0  71138.0   Diesel    NaN       NaN          0  1900      3
# 10  20950  25.0  31461.0   Petrol  192.0       0.0          0  1800      3
# 11  19950  22.0  43610.0   Petrol  192.0       0.0          0  1800      3
# 12  19600  25.0  32189.0   Petrol  192.0       0.0          0  1800      3
# 13  21500  31.0  23000.0   Petrol  192.0       1.0          0  1800      3
# 14  22500  32.0  34131.0   Petrol  192.0       1.0          0  1800      3
#
#     Weight
# 0     1165
# 1     1165
# 2     1165
# 3     1165
# 4     1170
# 5     1170
# 6     1245
# 7     1245
# 8     1185
# 9     1105
# 10    1185
# 11    1185
# 12    1185
# 13    1185
# 14    1185

# %% [markdown]
# PREPOCESSING THE DATASET

# %%
# descriptive statistics
print("The Dimension of the Data:",car.shape)
print("The size of dataset:" , car.size)
print("The list of columns\n\n", car.columns)
print("The data informartion\n\n",car.info())
print("The Data description\n\n" , car.describe())
print("Checking of the null values within the dataset:" , car.isnull().sum())
# Out:
# The Dimension of the Data: (1436, 10)
# The size of dataset: 14360
# The list of columns
#
#  Index(['Price', 'Age', 'KM', 'FuelType', 'HP', 'MetColor', 'Automatic', 'CC',
#        'Doors', 'Weight'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1436 non-null   float64
#  2   KM         1436 non-null   float64
#  3   FuelType   1436 non-null   object
#  4   HP         1436 non-null   float64
#  5   MetColor   1436 non-null   float64
#  6   Automatic  1436 non-null   object
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   int64
#  9   Weight     1436 non-null   int64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 155.7+ KB
# The data informartion
#
#  None
# The Data description
#
#                Price          Age             KM           HP     MetColor  \
# count   1436.000000  1436.000000    1436.000000  1436.000000  1436.000000
# mean   10730.824513    55.973538   68647.239972   101.478322     0.604457
# std     3626.964585    17.964211   37137.390678    14.737348     0.489137
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43505.750000    90.000000     0.000000
# 50%     9900.000000    60.000000   64000.000000   110.000000     1.000000
# 75%    11950.000000    68.000000   86916.000000   110.000000     1.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#                 CC        Doors      Weight
# count  1436.000000  1436.000000  1436.00000
# mean   1566.827994     4.033426  1072.45961
# std     187.182436     0.952677    52.64112
# min    1300.000000     2.000000  1000.00000
# 25%    1400.000000     3.000000  1040.00000
# 50%    1600.000000     4.000000  1070.00000
# 75%    1600.000000     5.000000  1085.00000
# max    2000.000000     5.000000  1615.00000
# Checking of the null values within the dataset: Price        0
# Age          0
# KM           0
# FuelType     0
# HP           0
# MetColor     0
# Automatic    0
# CC           0
# Doors        0
# Weight       0
# dtype: int64

# %% [markdown]
# 1 - detect some missing values.
# 2 - Metcolor and Automatic  are nominal variables.Therefore,neccessory to change the datatype.

# %%
#changing the data type
car[['MetColor','Automatic']] = car[['MetColor','Automatic']].astype('object')
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1336 non-null   float64
#  2   KM         1421 non-null   float64
#  3   FuelType   1336 non-null   object
#  4   HP         1430 non-null   float64
#  5   MetColor   1286 non-null   object
#  6   Automatic  1436 non-null   object
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   object
#  9   Weight     1436 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 123.4+ KB

# %%
car['Doors'].unique() # required to rename the values of Doors variable
# Out:
# array(['three', '3', '5', '4', 'four', 'five', '2'], dtype=object)

# %%
car['Doors'].replace('three',3,inplace=True)
car['Doors'].replace('four',4,inplace=True)
car['Doors'].replace('five',5,inplace=True)
car['Doors'].replace('3',3,inplace=True)
car['Doors'].replace('5',5,inplace=True)
car['Doors'].replace('4',4,inplace=True)
car['Doors'].replace('2',2,inplace=True)

# %%
car['Doors'].unique()
car['Doors'].astype('int')
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 1431    3
# 1432    3
# 1433    3
# 1434    3
# 1435    5
# Name: Doors, Length: 1436, dtype: int32

# %% [markdown]
# HANDLING THE MISSING VALUES

# %%
#checking for null values
car.isnull().sum()
# Out:
# Price          0
# Age          100
# KM            15
# FuelType     100
# HP             6
# MetColor     150
# Automatic      0
# CC             0
# Doors          0
# Weight         0
# dtype: int64

# %%
car.describe(exclude=['int','float'])
car.describe(include='O')
# Out:
#        FuelType  MetColor  Automatic
# count      1336    1286.0       1436
# unique        3       2.0          2
# top      Petrol       1.0          0
# freq       1177     868.0       1356

# %%
# visualise the data
sns.pairplot(car)

# %%
car['Age'].describe()
# Out:
# count    1336.000000
# mean       55.672156
# std        18.589804
# min         1.000000
# 25%        43.000000
# 50%        60.000000
# 75%        70.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
# mean < median .Therefore,age is left-skewed 
car['Age'].fillna(car['Age'].median() , inplace=True)
car['Age'].describe()
# Out:
# count    1436.000000
# mean       55.973538
# std        17.964211
# min         1.000000
# 25%        44.000000
# 50%        60.000000
# 75%        68.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
car['KM'].describe() # mean > median. so data distribution is right-skewed
# Out:
# count      1421.000000
# mean      68647.239972
# std       37333.023589
# min           1.000000
# 25%       43210.000000
# 50%       63634.000000
# 75%       87000.000000
# max      243000.000000
# Name: KM, dtype: float64

# %%
car['KM'].fillna(car['KM'].mean() , inplace=True)
car['KM'].mean()
# Out:
# 68647.23997185081

# %%
car['HP'].loc[5:16]
car['HP'].fillna(car['HP'].mean() , inplace = True)
car['HP'].mean()
# Out:
# 101.47832167832168

# %%
car['FuelType'].value_counts()
# Out:
# Petrol    1177
# Diesel     144
# CNG         15
# Name: FuelType, dtype: int64

# %%
car['FuelType'].mode() # most frequently occured values
# Out:
# 0    Petrol
# Name: FuelType, dtype: object

# %%
car['MetColor'].value_counts()
# Out:
# 1.0    868
# 0.0    418
# Name: MetColor, dtype: int64

# %%
car['MetColor'].mode()
# Out:
# 0    1.0
# Name: MetColor, dtype: object

# %%
car['FuelType'].fillna(car['FuelType'].value_counts().value_counts().index[0],inplace=True)
car['MetColor'].fillna(car['MetColor'].mode().index[0], inplace=True)

# %%
car.head(15)
# Out:
#     Price   Age            KM FuelType          HP  MetColor Automatic    CC  \
# 0   13500  23.0  46986.000000   Diesel   90.000000       1.0         0  2000
# 1   13750  23.0  72937.000000   Diesel   90.000000       1.0         0  2000
# 2   13950  24.0  41711.000000   Diesel   90.000000       0.0         0  2000
# 3   14950  26.0  48000.000000   Diesel   90.000000       0.0         0  2000
# 4   13750  30.0  38500.000000   Diesel   90.000000       0.0         0  2000
# 5   12950  32.0  61000.000000   Diesel   90.000000       0.0         0  2000
# 6   16900  27.0  68647.239972   Diesel  101.478322       0.0         0  2000
# 7   18600  30.0  75889.000000     1177   90.000000       1.0         0  2000
# 8   21500  27.0  19700.000000   Petrol  192.000000       0.0         0  1800
# 9   12950  23.0  71138.000000   Diesel  101.478322       0.0         0  1900
# 10  20950  25.0  31461.000000   Petrol  192.000000       0.0         0  1800
# 11  19950  22.0  43610.000000   Petrol  192.000000       0.0         0  1800
# 12  19600  25.0  32189.000000   Petrol  192.000000       0.0         0  1800
# 13  21500  31.0  23000.000000   Petrol  192.000000       1.0         0  1800
# 14  22500  32.0  34131.000000   Petrol  192.000000       1.0         0  1800
#
#     Doors  Weight
# 0       3    1165
# 1       3    1165
# 2       3    1165
# 3       3    1165
# 4       3    1170
# 5       3    1170
# 6       3    1245
# 7       3    1245
# 8       3    1185
# 9       3    1105
# 10      3    1185
# 11      3    1185
# 12      3    1185
# 13      3    1185
# 14      3    1185

# %%
sns.pairplot(car)

# %%
car.isnull().sum()
# Out:
# Price        0
# Age          0
# KM           0
# FuelType     0
# HP           0
# MetColor     0
# Automatic    0
# CC           0
# Doors        0
# Weight       0
# dtype: int64

# %% [markdown]
# *MISSING VALUES ARE SUCCESSFULLY TREATED*

# %% [markdown]
# HANDLING THE OUTLIERS

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# TO FIGURE OUT THE OUTLIERS

# %%
sns.boxplot(car['Price'])
# Out:
# <Axes: >

# %%
sns.distplot(car['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.boxplot(car['Age'])
# Out:
# <Axes: >

# %%
sns.boxplot(car['HP'])
# Out:
# <Axes: >

# %%
sns.boxplot(car['KM'])
# Out:
# <Axes: >

# %%
sns.boxplot(car['CC'])
# Out:
# <Axes: >

# %%
sns.boxplot(car['Weight'])
# Out:
# <Axes: >

# %%
lower_limit = car['Price'].mean() - 3*car['Price'].std()
print("lower_bound:",lower_limit)
upper_limit = car['Price'].mean() + 3*car['Price'].std()
print("upper_bound:", upper_limit)
# Out:
# lower_bound: -150.06924219591383
# upper_bound: 21611.71826726555

# %%
# detecting ouliers
price_outliers = car[(car['Price']>upper_limit) | (car['Price']<lower_limit)]
print(len(price_outliers))
# Out:
# 26

# %%
# creating new data frame by removing outliers
car_no_price_outliers = car[(car['Price']>lower_limit) & (car['Price']<upper_limit)]
car_no_price_outliers.shape
# Out:
# (1410, 10)

# %%
df1 = car.copy()

# %%
df1['Price'].describe()
# Out:
# count     1436.000000
# mean     10730.824513
# std       3626.964585
# min       4350.000000
# 25%       8450.000000
# 50%       9900.000000
# 75%      11950.000000
# max      32500.000000
# Name: Price, dtype: float64

# %%
# Before imputing Outliers

sns.distplot(df1['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df1.loc[df1.Price>upper_limit,'Price']=upper_limit
df1.loc[df1.Price<lower_limit,'Price']=lower_limit
df1['Price'].describe()

# After imputing Outliers

sns.distplot(df1['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df1['CC'].describe()
q1 = car['CC'].quantile(0.25)
q3 = car['CC'].quantile(0.75)
IQR = q3 - q1
print(q1, q3, IQR)
lower_limit = q1 - 1.5 * IQR
upper_limit = q3 + 1.5 * IQR
print("lower_bound:",lower_limit)
print("upper_bound:",upper_limit)
# Out:
# 1400.0 1600.0 200.0
# lower_bound: 1100.0
# upper_bound: 1900.0

# %%
CC_outliers = car[(car['CC']>upper_limit) | (car['CC']<lower_limit)]
print(len(CC_outliers))
# Out:
# 122

# %%
#imputing 'CC' outliers
df1.loc[df1.CC>upper_limit,'CC']=upper_limit
df1.loc[df1.CC<lower_limit,'CC']=lower_limit
df1['CC'].describe()
# Out:
# count    1436.000000
# mean     1558.356546
# std       168.733073
# min      1300.000000
# 25%      1400.000000
# 50%      1600.000000
# 75%      1600.000000
# max      1900.000000
# Name: CC, dtype: float64

# %% [markdown]
# SPLITTING THE DATA INTO TRAIN AND TEST SETS

# %%
from sklearn.model_selection import train_test_split 
#split the data into train and test sets
x=df1.KM.values.reshape(-1,1)
y=df1.Price.values.reshape(-1,1)
train_x,test_x,train_y,test_y = train_test_split(x,y,test_size=0.2)

# %%
print(train_x.shape)
print(test_x.shape)
print(train_y.shape)
print(test_y.shape)
# Out:
# (1148, 1)
# (288, 1)
# (1148, 1)
# (288, 1)

# %%
plt.hist(train_x)
# Out:
# (array([100., 260., 347., 241., 106.,  52.,  22.,  11.,   7.,   2.]),
#  array([1.000000e+00, 2.430090e+04, 4.860080e+04, 7.290070e+04,
#         9.720060e+04, 1.215005e+05, 1.458004e+05, 1.701003e+05,
#         1.944002e+05, 2.187001e+05, 2.430000e+05]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(test_x)
# Out:
# (array([13., 57., 73., 60., 36., 24., 10.,  6.,  6.,  3.]),
#  array([1.000000e+00, 2.181270e+04, 4.362440e+04, 6.543610e+04,
#         8.724780e+04, 1.090595e+05, 1.308712e+05, 1.526829e+05,
#         1.744946e+05, 1.963063e+05, 2.181180e+05]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(train_y)
# Out:
# (array([ 22., 156., 347., 264., 162.,  42.,  46.,  34.,  35.,  40.]),
#  array([ 4350.        ,  6076.17182673,  7802.34365345,  9528.51548018,
#         11254.68730691, 12980.85913363, 14707.03096036, 16433.20278709,
#         18159.37461381, 19885.54644054, 21611.71826727]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(test_y)
# Out:
# (array([ 9., 47., 95., 70., 26., 10.,  7.,  9.,  7.,  8.]),
#  array([ 4750.        ,  6436.17182673,  8122.34365345,  9808.51548018,
#         11494.68730691, 13180.85913363, 14867.03096036, 16553.20278709,
#         18239.37461381, 19925.54644054, 21611.71826727]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# APPLYING MODEL: LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(train_x,train_y)
# Out:
# LinearRegression()

# %%
train_y_pred=lm.predict(train_x)
test_y_pred=lm.predict(test_x)

plt.scatter(x,y)
plt.scatter(train_x,train_y_pred)
plt.scatter(test_x,test_y_pred,marker='.')

# %% [markdown]
# EVALUATING THE MODEL

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(train_y,train_y_pred)
rmse=np.sqrt(mse)
print("MSE: ",mse,"\nRMSE: ",rmse)
print("x.max:",x.max(),"\nx.min:",x.min(),"\ny.max:",y.max(),"\ny.min:",y.min())
# Out:
# MSE:  8215163.541424078
# RMSE:  2866.21065894049
# x.max: 243000.0
# x.min: 1.0
# y.max: 21611.71826726555
# y.min: 4350.0

# %%
mse=mean_squared_error(test_y,test_y_pred)
rmse=np.sqrt(mse)
print("MSE: ",mse,"\nRMSE: ",rmse)
print("x.max:",x.max(),"\nx.min:",x.min(),"\ny.max:",y.max(),"\ny.min:",y.min())
# Out:
# MSE:  7491049.596887433
# RMSE:  2736.9781871413284
# x.max: 243000.0
# x.min: 1.0
# y.max: 21611.71826726555
# y.min: 4350.0

# %%
newval=pd.DataFrame({'km':[4000,50000,95,100000]})
lm.predict(newval)
# Out:
# array([[14289.74592657],
#        [11726.1089929 ],
#        [14507.37640974],
#        [ 8939.54710847]])
